# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.random.rand(50)
y=np.random.rand(50)

# %%
x
# Out:
# array([0.46945048, 0.5814367 , 0.33718172, 0.42392334, 0.05491694,
#        0.06438199, 0.05846185, 0.9326705 , 0.79730195, 0.68227334,
#        0.29855333, 0.69625476, 0.42465509, 0.35105564, 0.82213907,
#        0.98606683, 0.47135052, 0.520337  , 0.75450445, 0.34846739,
#        0.64475613, 0.35311882, 0.72213082, 0.64267338, 0.32681788,
#        0.59296021, 0.29692056, 0.9317445 , 0.689462  , 0.9573955 ,
#        0.51803095, 0.69556018, 0.99268313, 0.42882323, 0.42668765,
#        0.24657141, 0.68514362, 0.44860053, 0.18617119, 0.56711633,
#        0.73945762, 0.10296292, 0.68180746, 0.60019386, 0.2093123 ,
#        0.5511092 , 0.80228714, 0.32991658, 0.17136126, 0.62242376])

# %%
y
# Out:
# array([0.33081212, 0.73705986, 0.5945026 , 0.86372949, 0.72392695,
#        0.96753064, 0.56059379, 0.53159626, 0.52686749, 0.60412003,
#        0.20959323, 0.81470433, 0.01040072, 0.36006506, 0.20822954,
#        0.12993142, 0.15303629, 0.29174229, 0.34196794, 0.91342529,
#        0.45132098, 0.84008585, 0.60938171, 0.01563702, 0.36694393,
#        0.17639468, 0.66189612, 0.24721642, 0.5400704 , 0.89972553,
#        0.73551531, 0.24818223, 0.94788358, 0.69732188, 0.0398123 ,
#        0.27488761, 0.27673638, 0.46906168, 0.57158515, 0.9524528 ,
#        0.3463514 , 0.5642556 , 0.83266785, 0.80357313, 0.80419269,
#        0.97879836, 0.6657426 , 0.27282216, 0.21940594, 0.63317454])

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y,c="red",marker="x")
plt.xlabel("This is my x axis")
plt.ylabel("This is my y axis")
plt.title("This is x VS y graph")
plt.grid()

# %%
x=np.linspace(1,10,100)
y=np.sin(x)

# %%
plt.figure(figsize=(8,2))
plt.plot(x,y,"--r")

# %%
x=['a','b','c','d','e']
y=np.random.rand(5)
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(x,y)
plt.figure(figsize=(5,3))

# %%
x=[2,3,4,5,6,7,8]
y=[3,4,5,6,7,8,9]
plt.plot(x,y)

# %%
plt.figure(figsize=(6,2))
plt.plot(x,y)

# %%
data=[1,1,1,1,3,3,3,3,5,5,5,5,5,5,5,7,7,7,9,9]
plt.hist(data)
# Out:
# (array([4., 0., 4., 0., 0., 7., 0., 3., 0., 2.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(6,2))
plt.hist(data)
# Out:
# (array([4., 0., 4., 0., 0., 7., 0., 3., 0., 2.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)
fig=plt.figure()
ax=fig.add_subplot(projection="3d")
plt.scatter(x,y,z ,alpha=0.9)
